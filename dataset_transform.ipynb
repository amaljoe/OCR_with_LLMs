# %%
import pandas as pd
import os
from PIL import Image

def get_dataset(dataset_path):
    if not os.path.exists(dataset_path):
        print("Dataset not found")
        return None
    dataset = []

    for folder in os.listdir(dataset_path):
        if not os.path.isdir(os.path.join(dataset_path, folder)):
            continue
        for i, file in enumerate(os.listdir(dataset_path + '/' + folder)):
            if not file.endswith('.png'):
                continue
            csv_file = dataset_path + '/' + folder + '/' + file[:-4] + '.csv'
            res_df = pd.read_csv(csv_file)
            image_path = os.path.join(dataset_path, folder, file)
            y = res_df['y'].to_numpy()
            image = Image.open(image_path).convert('RGB')
            width = image.width
            height = image.height
            text = ""
            for y_i in y:
                center_x = width / 2
                center_y = y_i + 75
                text += f'0 {center_x / width} {center_y / height} 1 {150/height}\n'
            dataset.append((file, image_path, text))
    return pd.DataFrame(dataset, columns=['file', 'image_path', 'text'])

dataset = get_dataset('synthetic_dataset')
dataset
# Out:
#             file                          image_path  \
# 0    c01-014.png   synthetic_dataset/135/c01-014.png
# 1    c01-009.png   synthetic_dataset/135/c01-009.png
# 2    g02-073.png   synthetic_dataset/307/g02-073.png
# 3    n06-194.png   synthetic_dataset/551/n06-194.png
# 4    n06-156.png   synthetic_dataset/551/n06-156.png
# 5    n06-182.png   synthetic_dataset/551/n06-182.png
# 6    n06-169.png   synthetic_dataset/551/n06-169.png
# 7    n06-186.png   synthetic_dataset/551/n06-186.png
# 8    n06-163.png   synthetic_dataset/551/n06-163.png
# 9    n06-201.png   synthetic_dataset/551/n06-201.png
# 10   n06-175.png   synthetic_dataset/551/n06-175.png
# 11   n06-148.png   synthetic_dataset/551/n06-148.png
# 12   m06-019.png   synthetic_dataset/551/m06-019.png
# 13  g06-042g.png  synthetic_dataset/338/g06-042g.png
# 14  g06-018g.png  synthetic_dataset/338/g06-018g.png
# 15  g06-045g.png  synthetic_dataset/338/g06-045g.png
# 16  g06-031g.png  synthetic_dataset/338/g06-031g.png
# ...

# %%
import shutil

dataset_folder = 'yolo_dataset'

for i in range(len(dataset)):
    file, image_path, text = dataset.iloc[i]
    with open(dataset_folder + '/' + file[:-4] + '.txt', 'w') as f:
        f.write(text)
    shutil.copy(image_path, dataset_folder + '/' + file)
